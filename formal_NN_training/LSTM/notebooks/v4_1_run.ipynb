# %% [markdown]
# # v4.1 notebook materializer
#
# This small launcher creates the full v4.1 notebook from the supplied v4.0 notebook plus the committed override payload.  Run the next cell once, then open the generated notebook and execute it from B0 onward.

# %%
from pathlib import Path
import subprocess
base = Path('/content/v4_0_profile_driven_timing_coverage.ipynb')
out = Path('/content/v4_1_policy_coverage_ceiling.ipynb')
subprocess.run(['python3', 'formal_NN_training/scripts/25_build_v4_1_notebook.py', '--base', str(base), '--out', str(out)], check=True)
print(out)
